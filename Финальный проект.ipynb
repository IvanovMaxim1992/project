# %% [markdown]
# !curl -O https://code.s3.yandex.net/data-scientist/ds-plus-final.db

# %% [markdown]
# ## Загрузка данных

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Путь к файлу базы данных
path_to_db = 'ds-plus-final.db'

# Создание подключения к базе данных
engine = create_engine(f'sqlite:///{path_to_db}', echo=False)

# Получение списка таблиц в базе данных
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", engine)
display(tables)
# Out:
#               name
# 0         data_arc
# 1        data_bulk
# 2   data_bulk_time
# 3   data_wire_time
# 4         contract
# 5         personal
# 6            phone
# 7         internet
# 8         data_gas
# 9        data_temp
# 10       data_wire

# %%
# Список нужных таблиц
required_tables = ['contract', 'personal', 'internet', 'phone']

# Загрузка данных из нужных таблиц
data = {}
for table in required_tables:
    data[table] = pd.read_sql(f"SELECT * FROM {table}", engine)

# Просмотр первых строк каждой таблицы
for table_name, df in data.items():
    print(f"Таблица: {table_name}")
    display(df.head())
# Out:
# Таблица: contract
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01      No        One year               No
# 2  3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01      No        One year               No
# 4  9237-HQITU  2019-09-01      No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges
# 0           Electronic check          29.85        31.04
# 1               Mailed check          56.95      2071.84
# 2               Mailed check          53.85       226.17
# 3  Bank transfer (automatic)           42.3       1960.6
# 4           Electronic check           70.7        353.5
# Таблица: personal
#    customerID  gender SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female             0     Yes         No
# 1  5575-GNVDE    Male             0      No         No
# ...

# %%
# Проверка информации о каждой таблице
for table_name, df in data.items():
    print(f"Информация о таблице: {table_name}")
    print(df.info())
    print("\n")
# Out:
# Информация о таблице: contract
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   object
#  7   TotalCharges      7043 non-null   object
# dtypes: object(8)
# memory usage: 440.3+ KB
# None
#
#
# Информация о таблице: personal
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
# ...

# %% [markdown]
# ---
#
# ### Анализ загруженных данных
#
# #### 1. **Таблица `contract`**
# - **Количество строк**: 7043
# - **Особенности**:
#   - Все столбцы имеют тип `object`, хотя некоторые из них (например, `MonthlyCharges` и `TotalCharges`) должны быть числовыми.
#   - В столбце `EndDate` значение "No" указывает, что клиент все еще активен.
#   - Столбец `BeginDate` содержит даты начала договоров.
#
# #### 2. **Таблица `personal`**
# - **Количество строк**: 7043
# - **Особенности**:
#   - Все столбцы также имеют тип `object`.
#   - Столбец `SeniorCitizen` (является ли клиент пенсионером) имеет значения "0" или "1", которые можно преобразовать в числовой тип.
#   - Столбцы `Partner` и `Dependents` содержат значения "Yes"/"No".
#
# #### 3. **Таблица `internet`**
# - **Количество строк**: 5517
# - **Особенности**:
#   - Таблица содержит информацию только о клиентах, которые пользуются интернет-услугами.
#   - Все столбцы имеют тип `object`.
#   - Столбцы `OnlineSecurity`, `OnlineBackup`, `DeviceProtection`, `TechSupport`, `StreamingTV`, `StreamingMovies` содержат значения "Yes"/"No".
#
# #### 4. **Таблица `phone`**
# - **Количество строк**: 6361
# - **Особенности**:
#   - Таблица содержит информацию только о клиентах, которые пользуются телефонными услугами.
#   - Столбец `MultipleLines` содержит значения "Yes"/"No".
#
# ---
#
# ### Наблюдения
# 1. **Размеры таблиц различаются**:
#    - Таблица `contract` содержит данные обо всех клиентах (7043 строки).
#    - Таблицы `internet` и `phone` содержат меньше строк, так как не все клиенты пользуются интернетом или телефонией.
#    - Это может привести к проблемам при объединении таблиц. Например, для клиентов без интернета или телефона в соответствующих таблицах не будет записей.
#
# 2. **Пропущенные значения**:
#    - Прямых пропусков (`NaN`) нет, но отсутствие данных в таблицах `internet` и `phone` можно интерпретировать как отсутствие соответствующих услуг у клиента.
#
# 3. **Типы данных**:
#    - Многие столбцы имеют тип `object`, хотя логичнее было бы использовать числовые типы (например, для `MonthlyCharges`, `TotalCharges`, `SeniorCitizen`).
#
# ---
#
# ### Что дальше?
# На основе этого анализа мы можем перейти к **шагу 2** — исследовательскому анализу и предобработке данных. Вот план действий:
#
# 1. **Обработка типов данных**:
#    - Преобразовать `MonthlyCharges` и `TotalCharges` в числовой формат.
#    - Преобразовать бинарные столбцы (`SeniorCitizen`, `Partner`, `Dependents`, `PaperlessBilling`, и другие с "Yes"/"No") в числовые значения.
#
# 2. **Обработка дат**:
#    - Преобразовать `BeginDate` и `EndDate` в формат даты.
#    - Для активных клиентов (`EndDate = "No"`) заменить значение на текущую дату.
#
# 3. **Объединение таблиц**:
#    - Объединить все таблицы по `customerID`.
#    - Добавить признаки для клиентов, которые не пользуются интернетом или телефонией.
#
# 4. **Генерация новых признаков**:
#    - Рассчитать длительность контракта.
#    - Создать целевую переменную на основе `EndDate`.
#
# 5. **Исследовательский анализ данных**:
#    - Проверить распределение признаков.
#    - Визуализировать соотношение ушедших и оставшихся клиентов.
#    - Провести корреляционный анализ.

# %%
RANDOM_STATE = 170225

# %% [markdown]
# ## Исследовательский анализ и предобработка данных

# %%
# Преобразование MonthlyCharges и TotalCharges в числовой формат
data['contract']['MonthlyCharges'] = pd.to_numeric(data['contract']['MonthlyCharges'], errors='coerce')
data['contract']['TotalCharges'] = pd.to_numeric(data['contract']['TotalCharges'], errors='coerce')

# Преобразование SeniorCitizen в числовой формат
data['personal']['SeniorCitizen'] = pd.to_numeric(data['personal']['SeniorCitizen'], errors='coerce')

# %%
# Проверка пропусков в таблице contract
print(data['contract'].isnull().sum())
# Out:
# customerID           0
# BeginDate            0
# EndDate              0
# Type                 0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# dtype: int64

# %%
data['contract']['TotalCharges'] = data['contract']['TotalCharges'].fillna(0)

# %%
# Список бинарных столбцов
binary_columns = [
    'PaperlessBilling', 'Partner', 'Dependents',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines'
]

# Преобразование бинарных признаков
for table in ['contract', 'personal', 'internet', 'phone']:
    for col in binary_columns:
        if col in data[table].columns:
            data[table][col] = data[table][col].map({'Yes': 1, 'No': 0})

# %%
# Преобразование BeginDate в формат даты
data['contract']['BeginDate'] = pd.to_datetime(data['contract']['BeginDate'])

# Замена "No" в EndDate на текущую дату 
current_date = pd.to_datetime('2025-02-17')
data['contract']['EndDate'] = data['contract']['EndDate'].replace('No', current_date)
data['contract']['EndDate'] = pd.to_datetime(data['contract']['EndDate'])

# %%
data['contract']['ContractDuration'] = (data['contract']['EndDate'] - data['contract']['BeginDate']).dt.days

# %%
# Объединение таблиц
merged_data = data['contract'].merge(
    data['personal'], on='customerID', how='left'
).merge(
    data['internet'], on='customerID', how='left'
).merge(
    data['phone'], left_on='customerID', right_on='CustomerId', how='left'
)

# Заполнение пропусков для клиентов без интернета
merged_data['InternetService'] = merged_data['InternetService'].fillna('No')
for col in ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']:
    merged_data[col] = merged_data[col].fillna(0)

# Заполнение пропусков для клиентов без телефона
merged_data['MultipleLines'] = merged_data['MultipleLines'].fillna(0)
merged_data['CustomerId'] = merged_data['CustomerId'].fillna('No')

# %%
merged_data['Churn'] = (merged_data['EndDate'] != current_date).astype(int)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Распределение числовых признаков
numeric_features = ['MonthlyCharges', 'TotalCharges', 'ContractDuration']
for feature in numeric_features:
    plt.figure(figsize=(8, 4))
    sns.histplot(merged_data[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %%
sns.countplot(x='Churn', data=merged_data)
plt.title('Churn Distribution')
plt.show()

# %%
correlation_matrix = merged_data[numeric_features + ['Churn']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ---
#
# ### Анализ распределения признаков
#
# #### 1. **Распределение `MonthlyCharges`**
# - Распределение имеет два пика: один в районе 20 долларов, другой — между 70 и 80 долларами.
# - Это может указывать на наличие двух основных тарифных планов или групп клиентов с разными потребностями.
#
# #### 2. **Распределение `TotalCharges`**
# - Большинство клиентов имеют общие расходы до 2000 долларов.
# - Распределение постепенно снижается для более высоких значений, что говорит о том, что большинство клиентов не используют услуги слишком долго или не тратят слишком много денег.
#
# #### 3. **Распределение `ContractDuration`**
# - Пик в районе 700 дней (около 2 лет) может указывать на популярность годовых контрактов.
# - Также есть пик в районе 4000 дней (около 11 лет), что может быть связано с долгосрочными клиентами.
#
# ---
#
# ### Анализ соотношения ушедших и оставшихся клиентов
#
# #### 4. **График `Churn Distribution`**
# - Из графика видно, что большинство клиентов (около 6000) остались, а около 1000 ушли.
# - Это указывает на то, что дисбаланс классов присутствует, но не очень сильный.
#
# ---
#
# ### Корреляционный анализ
#
# #### 5. **Матрица корреляции**
# - **`MonthlyCharges` и `TotalCharges`**: сильная положительная корреляция (0.63). Это логично, так как общие расходы зависят от ежемесячных расходов.
# - **`ContractDuration` и `Churn`**: сильная отрицательная корреляция (-0.69). Это означает, что чем дольше клиент пользуется услугами, тем меньше вероятность его ухода.
# - **`MonthlyCharges` и `Churn`**: слабая положительная корреляция (0.15). Возможно, клиенты с более дорогими тарифами чаще уходят.
#
# ---
#
# ### Выводы
#
# #### 1. **Важные наблюдения**
# - Существуют две группы клиентов с разными ежемесячными расходами.
# - Длительность контракта сильно влияет на вероятность ухода клиента.
# - Наличие дисбаланса классов, но он не критичен Можно использовать модели которые это учитывают.

# %%
# Выделяем признаки и целевую переменную
X = merged_data.drop(columns=['customerID', 'BeginDate', 'EndDate', 'Churn'])
y = merged_data['Churn']

# Разделяем данные на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=RANDOM_STATE, stratify=y
)

# Категориальные и числовые признаки
categorical_features = ['Type', 'PaymentMethod', 'gender', 'InternetService']
numeric_features = [
    'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
    'SeniorCitizen', 'Partner', 'Dependents', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines'
]

# Создаем преобразователь для категориальных признаков
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numeric_features),
        ('cat', OneHotEncoder(drop='first'), categorical_features)
    ]
)

# %%
# Создаем pipeline с преобразованием и моделью
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(random_state=RANDOM_STATE))
])

# Обучаем модель
pipeline.fit(X_train, y_train)

# Получаем важность признаков
feature_names = (
    numeric_features +
    list(pipeline.named_steps['preprocessor'].transformers_[1][1].get_feature_names_out(categorical_features))
)
importances = pipeline.named_steps['classifier'].feature_importances_

# Создаем DataFrame для удобства анализа
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Выводим топ-10 важных признаков
print(importance_df.head(10))
# Out:
#              Feature  Importance
# 2       TotalCharges    0.294187
# 1     MonthlyCharges    0.228734
# 18       gender_Male    0.036970
# 12     MultipleLines    0.032347
# 4            Partner    0.030922
# 0   PaperlessBilling    0.030745
# 5         Dependents    0.030130
# 14     Type_Two year    0.029516
# 8   DeviceProtection    0.026409
# 3      SeniorCitizen    0.026276

# %%
# Визуализация важности признаков
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df.head(10))
plt.title('Top 10 Feature Importances')
plt.show()

# %% [markdown]
# ---
#
# ### Анализ важности признаков (без `ContractDuration`)
#
# #### 1. **Топ-10 важных признаков**
# Вот основные наблюдения:
#
# 1. **`TotalCharges` (0.294)**:
#    - Общие расходы клиента стали самым важным признаком. Это логично, так как клиенты, которые платят больше, могут быть более склонны к уходу.
#
# 2. **`MonthlyCharges` (0.229)**:
#    - Ежемесячные расходы также имеют высокую важность. Возможно, клиенты с более дорогими тарифами чаще уходят.
#
# 3. **`gender_Male` (0.037)**:
#    - Пол клиента (`Male`) имеет умеренное влияние на отток. Это может быть связано с различиями в поведении мужчин и женщин.
#
# 4. **`MultipleLines` (0.032)**:
#    - Подключение телефона к нескольким линиям одновременно оказывает умеренное влияние на отток.
#
# 5. **`Partner` (0.031)**:
#    - Наличие супруга или супруги также влияет на вероятность ухода клиента.
#
# 6. **`PaperlessBilling` (0.031)**:
#    - Электронный расчетный лист имеет умеренную важность. Возможно, клиенты, использующие электронные чеки, реже уходят.
#
# 7. **`Dependents` (0.030)**:
#    - Наличие детей также влияет на вероятность ухода клиента.
#
# 8. **`Type_Two year` (0.030)**:
#    - Клиенты, заключившие долгосрочные контракты (на 2 года), реже уходят.
#
# 9. **`DeviceProtection` (0.026)**:
#    - Антивирусная защита оказывает умеренное влияние на отток.
#
# 10. **`SeniorCitizen` (0.026)**:
#     - Пенсионеры также имеют умеренное влияние на вероятность ухода.
#
# ---
#
# ### Выводы
#
# 1. **Изменение важности признаков**:
#    - После исключения `ContractDuration` другие признаки, такие как `TotalCharges`, `MonthlyCharges`, и `gender_Male`, стали более значимыми.
#    - Это подтверждает, что `ContractDuration` действительно мог вызывать утечку данных.
#
# 2. **Новые важные признаки**:
#    - `TotalCharges` и `MonthlyCharges` теперь являются ключевыми факторами, влияющими на отток клиентов.
#    - Также важно учитывать тип контракта (`Type_Two year`), наличие супруга (`Partner`) и использование электронного расчетного листа (`PaperlessBilling`).
#
# 3. **Утечка данных**:
#    - Исключение `ContractDuration` помогло избежать возможной утечки данных, так как этот признак напрямую зависел от даты окончания договора.
#
# ---
