# %% [markdown]
# ### Описание проекта
#
# #### 1. Введение
#
# **1.1 Цель проекта**
#
# Цель данного проекта — разработать модель машинного обучения для предсказания оттока клиентов телекоммуникационной компании. Отток клиентов является ключевым показателем эффективности бизнеса, и его своевременное выявление позволяет принять меры по удержанию клиентов.

# %%
# Устанавливаем RANDOM_STATE
RANDOM_STATE = 17225

# Импортируем библиотеки
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from catboost import CatBoostClassifier
from category_encoders import TargetEncoder
import shap
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, PrecisionRecallDisplay, precision_recall_curve, f1_score

# %% [markdown]
# ## Загрузка данных

# %%
# Подключаемся к базе
path_to_db = 'ds-plus-final.db'
engine = create_engine(f'sqlite:///{path_to_db}', echo=False)

# Проверяем таблицы в базе
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", engine)
print(tables)
# Out:
#               name
# 0         data_arc
# 1        data_bulk
# 2   data_bulk_time
# 3   data_wire_time
# 4         contract
# 5         personal
# 6            phone
# 7         internet
# 8         data_gas
# 9        data_temp
# 10       data_wire

# %%
# Загрузка таблиц
contract = pd.read_sql("SELECT * FROM contract", engine)
personal = pd.read_sql("SELECT * FROM personal", engine)
internet = pd.read_sql("SELECT * FROM internet", engine)
phone = pd.read_sql("SELECT * FROM phone", engine)

# Проверка размеров таблиц
print("Размеры таблиц:")
print("contract:", contract.shape)
print("personal:", personal.shape)
print("internet:", internet.shape)
print("phone:", phone.shape)
# Out:
# Размеры таблиц:
# contract: (7043, 8)
# personal: (7043, 5)
# internet: (5517, 8)
# phone: (6361, 2)

# %%
display(contract.head())
display(personal.head())
display(internet.head())
display(phone.head())
# Out:
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01      No        One year               No
# 2  3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01      No        One year               No
# 4  9237-HQITU  2019-09-01      No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges
# 0           Electronic check          29.85        31.04
# 1               Mailed check          56.95      2071.84
# 2               Mailed check          53.85       226.17
# 3  Bank transfer (automatic)           42.3       1960.6
# 4           Electronic check           70.7        353.5
#    customerID  gender SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female             0     Yes         No
# 1  5575-GNVDE    Male             0      No         No
# ...

# %% [markdown]
# ## Исследовательский анализ и предобработку данных

# %%
# Переименовываем колонку в таблице phone для корректного объединения
phone = phone.rename(columns={'CustomerId': 'customerID'})

# Объединяем все таблицы по customerID с сохранением всех записей
df = contract.merge(personal, on='customerID', how='outer') \
             .merge(internet, on='customerID', how='outer') \
             .merge(phone, on='customerID', how='outer')

# Проверяем итоговые размеры и пропуски
print(f"Итоговый размер таблицы: {df.shape}")
print("Пропуски в данных:")
print(df.isnull().sum())

# Заполнение пропусков в интернет-услугах
internet_services = ['InternetService', 'OnlineSecurity', 'OnlineBackup',
                     'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# Заполняем пропуски в интернет-колонках значением "No internet service"
df[internet_services] = df[internet_services].fillna('No')

# Заполняем пропуски в телефонной услуге значением "No phone service"
df['MultipleLines'] = df['MultipleLines'].fillna('No')

# Проверяем оставшиеся пропуски
print("\nПропуски после обработки:")
print(df.isnull().sum())
# Out:
# Итоговый размер таблицы: (7043, 20)
# Пропуски в данных:
# customerID             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# MultipleLines        682
# dtype: int64
#
# Пропуски после обработки:
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# InternetService     0
# OnlineSecurity      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   object
#  7   TotalCharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   object
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# ## Исследовательский анализ и предобработа данных

# %%
# 1. Преобразование числовых колонок в float
# Проверяем текущие типы данных
print("Типы данных до преобразования:")
print(df[['MonthlyCharges', 'TotalCharges']].dtypes)

# Обрабатываем TotalCharges: заменяем пустые строки на NaN и преобразуем
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Заполняем пропуски в TotalCharges нулями (если есть)
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# Приводим к типу float
df['MonthlyCharges'] = df['MonthlyCharges'].astype(float)
df['TotalCharges'] = df['TotalCharges'].astype(float)

# 2. Создаем целевую переменную
# Сохраняем оригинальный EndDate для расчета длительности контракта
df['Churn'] = df['EndDate'].apply(lambda x: 0 if x == 'No' else 1)

# 3. Заменяем 'No' в EndDate на дату выгрузки (1 февраля 2020)
df['EndDate'] = df['EndDate'].replace('No', '2020-02-01')

# 4. Преобразуем колонки с датами в datetime
df['BeginDate'] = pd.to_datetime(df['BeginDate'])
df['EndDate'] = pd.to_datetime(df['EndDate'])

# Проверяем результаты
print("\nТипы данных после преобразования:")
print(df[['MonthlyCharges', 'TotalCharges', 'BeginDate', 'EndDate']].dtypes)
print("\nПример данных:")
display(df[['BeginDate', 'EndDate', 'Churn']].head())
# Out:
# Типы данных до преобразования:
# MonthlyCharges    object
# TotalCharges      object
# dtype: object
#
# Типы данных после преобразования:
# MonthlyCharges           float64
# TotalCharges             float64
# BeginDate         datetime64[ns]
# EndDate           datetime64[ns]
# dtype: object
#
# Пример данных:
#    BeginDate    EndDate  Churn
# 0 2019-05-01 2020-02-01      0
# 1 2019-05-01 2020-02-01      0
# 2 2019-09-01 2020-02-01      0
# 3 2018-12-01 2020-02-01      0
# 4 2019-09-01 2020-02-01      0

# %%
# Получаем список колонок типа object
object_columns = df.select_dtypes(include='object').columns.tolist()

print(f"Колонки типа object: {object_columns}\n")

# Выводим уникальные значения для каждой колонки
for col in object_columns:
    print(f"**{col}**")
    print(f"Уникальных значений: {df[col].nunique()}")
    print(df[col].unique())
    print("-" * 50)
# Out:
# Колонки типа object: ['customerID', 'Type', 'PaperlessBilling', 'PaymentMethod', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines']
#
# **customerID**
# Уникальных значений: 7043
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# --------------------------------------------------
# **Type**
# Уникальных значений: 3
# ['One year' 'Month-to-month' 'Two year']
# --------------------------------------------------
# **PaperlessBilling**
# Уникальных значений: 2
# ['Yes' 'No']
# --------------------------------------------------
# **PaymentMethod**
# Уникальных значений: 4
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# --------------------------------------------------
# **gender**
# Уникальных значений: 2
# ['Female' 'Male']
# ...

# %%
# Сохраняем удаленные строки для анализа
mask = (df['InternetService'] == 'No') & (df['MultipleLines'] == 'No')
removed_clients = df[mask]

# Анализ ушедших среди удаленных клиентов
print("Статус ухода удаленных клиентов:")
print(removed_clients['Churn'].value_counts())

# Проверка даты окончания договора
print("\nДаты окончания договора удаленных клиентов:")
print(removed_clients[['BeginDate', 'EndDate']].head())

# Удаляем строки из основного DataFrame
df = df[~mask]

# Итоговая проверка
print(f"\nОставшиеся строки: {df.shape[0]}")
# Out:
# Статус ухода удаленных клиентов:
# Churn
# 0    1090
# 1      94
# Name: count, dtype: int64
#
# Даты окончания договора удаленных клиентов:
#     BeginDate    EndDate
# 23 2019-11-01 2020-02-01
# 24 2019-09-01 2020-02-01
# 27 2015-08-01 2016-03-01
# 28 2017-12-01 2020-02-01
# 29 2014-05-01 2017-02-01
#
# Оставшиеся строки: 5859

# %% [markdown]
# 1. **Статистика удаленных клиентов:**
#    - Активных клиентов (Churn=0): 1090
#    - Ушедших клиентов (Churn=1): 94
#
# 2. **Ключевые выводы:**
#
#    - **Основная часть (92%) удаленных клиентов все еще активна** на момент выгрузки данных (2020-02-01)
#    - Лишь небольшая доля (8%) действительно ушла
#
# 3. **Почему это важно:**
#
#    - Эти клиенты не используют основные услуги оператора (нет ни интернета, ни телефонии)
#    - Они могут быть:
#      - Новыми клиентами, которые еще не подключили услуги
#      - Клиентами в процессе отключения
#      - Ошибками в данных
#    - Их поведение существенно отличается от остальных клиентов и может исказить модель
#
# 4. **Обоснование удаления:**
#
#    - Эти клиенты не представляют ценности для прогнозирования оттока среди активных пользователей услуг
#    - Их особый статус (отсутствие основных услуг) требует отдельного анализа
#    - После удаления модель будет фокусироваться на клиентах, которые действительно используют услуги компании

# %%
# Настройки графика
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")

# Расчет распределения
churn_dist = df['Churn'].value_counts(normalize=True) * 100

# Построение графика с исправлением предупреждения
ax = sns.barplot(
    x=churn_dist.index.astype(str),  # Приводим индексы к строкам
    y=churn_dist.values,
    hue=churn_dist.index.astype(str),  # Указываем hue
    palette=['#2ecc71', '#e74c3c'],
    legend=False  # Отключаем легенду
)

# Форматирование графика
plt.title('Распределение целевого признака (Churn)', fontsize=14, pad=20)
plt.xlabel('Статус оттока', fontsize=12)
plt.ylabel('Процент клиентов', fontsize=12)
plt.xticks(ticks=[0, 1], labels=['Активные клиенты', 'Ушедшие клиенты'])

# Добавление процентных значений
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2., height + 1,
            f'{height:.1f}%',
            ha="center", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# 1. Проверка адекватности дат
print("Минимальная дата начала: ", df['BeginDate'].min())
print("Максимальная дата начала: ", df['BeginDate'].max())
print("Максимальная дата окончания: ", df['EndDate'].max())

# Проверка на аномальные значения в датах
anomalies = df[df['BeginDate'] > df['EndDate']]
if anomalies.shape[0] > 0:
    print(f"\nОбнаружено {anomalies.shape[0]} аномальных записей с BeginDate > EndDate")
else:
    print("\nАномалий в датах не обнаружено")

# 2. Анализ MonthlyCharges и TotalCharges
# Описательная статистика
print("\nОписательная статистика MonthlyCharges:")
print(df['MonthlyCharges'].describe())

print("\nОписательная статистика TotalCharges:")
print(df['TotalCharges'].describe())

# Визуализация распределений
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['MonthlyCharges'], bins=30, kde=True)
plt.title('Распределение MonthlyCharges')
plt.xlabel('Ежемесячные платежи')

plt.subplot(1, 2, 2)
sns.histplot(df['TotalCharges'], bins=30, kde=True)
plt.title('Распределение TotalCharges')
plt.xlabel('Общие платежи')

plt.show()

# Поиск выбросов через межквартильный размах
def find_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column[(column < lower_bound) | (column > upper_bound)]

monthly_outliers = find_outliers(df['MonthlyCharges'])
total_outliers = find_outliers(df['TotalCharges'])

print(f"\nВыбросы в MonthlyCharges: {monthly_outliers.shape[0]} записей")
print(f"Выбросы в TotalCharges: {total_outliers.shape[0]} записей")
# Удаляем строки с выбросами в TotalCharges
df = df[~df['TotalCharges'].isin(total_outliers)]
print(f"Удалено {len(total_outliers)} строк с выбросами.")
# Out:
# Минимальная дата начала:  2013-10-01 00:00:00
# Максимальная дата начала:  2020-02-01 00:00:00
# Максимальная дата окончания:  2020-02-01 00:00:00
#
# Аномалий в датах не обнаружено
#
# Описательная статистика MonthlyCharges:
# count    5859.000000
# mean       73.816300
# std        24.506805
# min        22.950000
# 25%        55.200000
# 50%        77.000000
# 75%        93.825000
# max       118.750000
# Name: MonthlyCharges, dtype: float64
#
# Описательная статистика TotalCharges:
# count    5859.000000
# mean     2441.809310
# std      2166.472031
# min         0.000000
# 25%       632.575000
# 50%      1772.420000
# 75%      3751.555000
# max      9221.380000
# Name: TotalCharges, dtype: float64
# Выбросы в MonthlyCharges: 0 записей
# Выбросы в TotalCharges: 29 записей
# Удалено 29 строк с выбросами.

# %%
# Количество подключенных дополнительных услуг
additional_services = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                       'TechSupport', 'StreamingTV', 'StreamingMovies']
df['NumAdditionalServices'] = df[additional_services].apply(
    lambda row: sum(row != 'No'), axis=1
)

# %%
# Создать новые признаки:
# 1. Продолжительность контракта
df['ContractDuration'] = (df['EndDate'] - df['BeginDate']).dt.days

# 2. Средний ежемесячный платеж
df['AvgMonthlyCharge'] = df['TotalCharges'] / df['ContractDuration']

# 3. Взаимодействия между признаками
df['Internet_Services_Count'] = df[['OnlineSecurity', 'OnlineBackup', 
                                    'DeviceProtection', 'TechSupport']].apply(lambda x: sum(x == 'Yes'), axis=1)

# %%
df['HighCostUser'] = (df['MonthlyCharges'] > df['MonthlyCharges'].median()).astype(int)

# %%
df['HasAdditionalServices'] = (df['NumAdditionalServices'] > 0).astype(int)
df['HasStreamingServices'] = ((df['StreamingTV'] == 'Yes') | (df['StreamingMovies'] == 'Yes')).astype(int)
df['ProtectionLevel'] = df[['DeviceProtection', 'TechSupport']].apply(
    lambda row: sum(row == 'Yes'), axis=1
)

# %%
df['AutoPayment'] = df['PaymentMethod'].isin([
    'Bank transfer (automatic)', 'Credit card (automatic)'
]).astype(int)
df['PaymentTypeNumeric'] = df['Type'].map({
    'Month-to-month': 1,
    'One year': 12,
    'Two year': 24
})

# %%
df['LogMonthlyCharges'] = np.log1p(df['MonthlyCharges'])
df['LogTotalCharges'] = np.log1p(df['TotalCharges'])

# %%
df['BillingPaymentInteraction'] = (df['PaperlessBilling'] == 'Yes') & (df['AutoPayment'] == 1)
df['BillingPaymentInteraction'] = df['BillingPaymentInteraction'].astype(int)

# %%
df['HasDSL'] = (df['InternetService'] == 'DSL').astype(int)
df['HasFiberOptic'] = (df['InternetService'] == 'Fiber optic').astype(int)

# %%
# Список новых признаков
new_features = [
    'NumAdditionalServices', 'HighCostUser', 'HasAdditionalServices', 'HasStreamingServices',
    'ProtectionLevel', 'AutoPayment', 'PaymentTypeNumeric', 'LogMonthlyCharges', 'LogTotalCharges',
    'BillingPaymentInteraction', 'HasDSL', 'HasFiberOptic'
]

# Выводим таблицу с новыми признаками
display(df[new_features].head())

# Описательная статистика для числовых признаков
print("\nОписательная статистика для числовых признаков:")
display(df[new_features].select_dtypes(include=['int64', 'float64']).describe())

# Распределение категориальных признаков
print("\nРаспределение категориальных признаков:")
for col in df[new_features].select_dtypes(include='object').columns:
    print(f"\n**{col}**")
    print(df[col].value_counts())
# Out:
#    NumAdditionalServices  HighCostUser  HasAdditionalServices  \
# 0                      3             0                      1
# 1                      1             0                      1
# 2                      1             0                      1
# 3                      4             1                      1
# 4                      2             1                      1
#
#    HasStreamingServices  ProtectionLevel  AutoPayment  PaymentTypeNumeric  \
# 0                     1                1            0                  12
# 1                     1                0            0                   1
# 2                     0                1            0                   1
# 3                     1                1            0                   1
# 4                     1                1            0                   1
#
#    LogMonthlyCharges  LogTotalCharges  BillingPaymentInteraction  HasDSL  \
# ...

# %%
df = df.drop(columns=['customerID', 'BeginDate', 'EndDate'])
# Определяем категориальные признаки
categorical_features = df.select_dtypes(include=['object']).columns.tolist()

# Определяем числовые признаки
numeric_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Убираем целевую переменную из числовых признаков
if 'Churn' in numeric_features:
    numeric_features.remove('Churn')

print("Категориальные признаки:", categorical_features)
print("Числовые признаки:", numeric_features)
# Out:
# Категориальные признаки: ['Type', 'PaperlessBilling', 'PaymentMethod', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines']
# Числовые признаки: ['MonthlyCharges', 'TotalCharges', 'NumAdditionalServices', 'ContractDuration', 'AvgMonthlyCharge', 'Internet_Services_Count', 'ProtectionLevel', 'PaymentTypeNumeric', 'LogMonthlyCharges', 'LogTotalCharges']

# %%
from category_encoders import TargetEncoder

# Создаем копию данных
df_encoded = df.copy()

# Применяем Target Encoding для категориальных признаков
encoder = TargetEncoder()
df_encoded[categorical_features] = encoder.fit_transform(df[categorical_features], df['Churn'])

# Проверяем результат
print("\nПример данных после Target Encoding:")
display(df_encoded[categorical_features].head())
# Out:
# Пример данных после Target Encoding:
#        Type  PaperlessBilling  PaymentMethod    gender  SeniorCitizen  \
# 0  0.246587          0.181057       0.086646  0.165860       0.164410
# 1  0.118963          0.156873       0.086646  0.179496       0.164410
# 2  0.118963          0.181057       0.152423  0.179496       0.164410
# 3  0.118963          0.181057       0.152423  0.179496       0.208333
# 4  0.118963          0.181057       0.086646  0.165860       0.208333
#
#     Partner  Dependents  InternetService  OnlineSecurity  OnlineBackup  \
# 0  0.227972    0.192734         0.142916        0.154247      0.233333
# 1  0.119529    0.165002         0.142916        0.154247      0.130321
# 2  0.119529    0.165002         0.194001        0.154247      0.130321
# 3  0.227972    0.165002         0.194001        0.154247      0.233333
# 4  0.227972    0.165002         0.194001        0.154247      0.130321
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  MultipleLines
# ...

# %%
# Объединяем числовые и закодированные категориальные признаки
all_features = numeric_features + categorical_features

# Вычисляем корреляцию всех признаков с Churn
correlation_all = df_encoded[all_features].corrwith(df_encoded['Churn'])

print("\nКорреляция всех признаков с Churn (с Target Encoding):")
print(correlation_all.sort_values(ascending=False))
# Out:
# Корреляция всех признаков с Churn (с Target Encoding):
# NumAdditionalServices      0.172439
# Type                       0.168010
# MultipleLines              0.154137
# PaymentTypeNumeric         0.153636
# Internet_Services_Count    0.145483
# Partner                    0.143414
# AvgMonthlyCharge           0.136995
# OnlineBackup               0.134113
# PaymentMethod              0.133508
# MonthlyCharges             0.133442
# StreamingMovies            0.126588
# DeviceProtection           0.126063
# LogTotalCharges            0.124854
# StreamingTV                0.110572
# ProtectionLevel            0.110317
# LogMonthlyCharges          0.108927
# OnlineSecurity             0.067860
# InternetService            0.066462
# TechSupport                0.047663
# SeniorCitizen              0.045526
# Dependents                 0.032887
# PaperlessBilling           0.030401
# TotalCharges               0.025850
# gender                     0.018035
# ...

# %%
# Визуализация корреляции
plt.figure(figsize=(10, 8))
correlation_all.sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title("Корреляция признаков с Churn")
plt.ylabel("Корреляция")
plt.xlabel("Признаки")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Разделяем данные на обучающую и тестовую выборки
X = df.drop(columns=['Churn'])
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=RANDOM_STATE, stratify=y
)

# Определяем категориальные признаки
categorical_features = X.select_dtypes(include=['object']).columns.tolist()

# Создаем и обучаем модель CatBoost
model = CatBoostClassifier(
    random_state=RANDOM_STATE,
    verbose=0,  # Отключаем вывод логов
    cat_features=categorical_features  # Указываем категориальные признаки
)

model.fit(X_train, y_train)

# %%
# Создаем объяснитель SHAP
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train)

# Глобальная важность признаков
shap.summary_plot(shap_values, X_train, plot_type="bar")

# Детальный анализ влияния признаков
shap.summary_plot(shap_values, X_train)

# %% [markdown]
# ## Моделирование

# %%
# Определяем числовые и категориальные признаки
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = X.select_dtypes(include=['object']).columns.tolist()

# Обработка числовых признаков
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),  # Заполнение пропусков медианой
    ('scaler', StandardScaler())                   # Масштабирование
])

# Обработка категориальных признаков
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Заполнение пропусков наиболее частым значением
    ('target', TargetEncoder())                            # Target Encoding
])

# Объединяем преобразования в ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
# Настройка кросс-валидации с учётом дисбаланса
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# Список моделей и их параметров
models = [
    {
        'name': 'Decision Tree',
        'estimator': DecisionTreeClassifier(random_state=RANDOM_STATE),
        'params': {
            'model__max_depth': [3, 5, 7, None],
            'model__min_samples_leaf': [1, 5, 10],
            'model__class_weight': [None, 'balanced']
        }
    },
    {
        'name': 'Random Forest',
        'estimator': RandomForestClassifier(random_state=RANDOM_STATE),
        'params': {
            'model__n_estimators': [100, 200],
            'model__max_depth': [3, 5, 7],
            'model__class_weight': [None, 'balanced']
        }
    },
    {
        'name': 'Gradient Boosting',
        'estimator': HistGradientBoostingClassifier(random_state=RANDOM_STATE),
        'params': {
            'model__learning_rate': [0.15, 0.2],
            'model__max_depth': [3, 5, 7, 9],
            'model__l2_regularization': [0.5, 1.0],
            'model__max_iter': [300, 500],
            'model__class_weight': [None, 'balanced'],
            'model__early_stopping': [True, False] 
        }
    },
    {
        'name': 'Logistic Regression',
        'estimator': LogisticRegression(random_state=RANDOM_STATE, max_iter=1000),
        'params': {
            'model__C': [0.1, 1, 10],
            'model__penalty': ['l1', 'l2'],
            'model__class_weight': [None, 'balanced'],
            'model__solver': ['liblinear']
        }
    }
]

# Функция для подбора параметров
def perform_grid_search(models, X_train, y_train):
    results = []
    
    for model_info in models:
        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('model', model_info['estimator'])
        ])
        
        grid_search = GridSearchCV(
            estimator=pipeline,
            param_grid=model_info['params'],
            cv=cv,
            scoring='roc_auc',
            n_jobs=-1,
            verbose=1
        )
        
        grid_search.fit(X_train, y_train)
        
        results.append({
            'model_name': model_info['name'],
            'best_params': grid_search.best_params_,
            'best_score': grid_search.best_score_,
            'cv_results': grid_search.cv_results_
        })
        
        print(f"Модель: {model_info['name']}")
        print(f"Лучшие параметры: {grid_search.best_params_}")
        print(f"Лучший ROC-AUC: {grid_search.best_score_:.4f}\n")
    
    return results

# Запуск подбора параметров
grid_search_results = perform_grid_search(models, X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Модель: Decision Tree
# Лучшие параметры: {'model__class_weight': 'balanced', 'model__max_depth': 5, 'model__min_samples_leaf': 5}
# Лучший ROC-AUC: 0.7901
#
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Модель: Random Forest
# Лучшие параметры: {'model__class_weight': None, 'model__max_depth': 7, 'model__n_estimators': 200}
# Лучший ROC-AUC: 0.8199
#
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Модель: Gradient Boosting
# Лучшие параметры: {'model__class_weight': None, 'model__early_stopping': False, 'model__l2_regularization': 1.0, 'model__learning_rate': 0.2, 'model__max_depth': 3, 'model__max_iter': 500}
# Лучший ROC-AUC: 0.8830
#
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Модель: Logistic Regression
# Лучшие параметры: {'model__C': 10, 'model__class_weight': None, 'model__penalty': 'l1', 'model__solver': 'liblinear'}
# Лучший ROC-AUC: 0.8091

# %% [markdown]
# ## Тест

# %%
# 1. Автоматический выбор лучшей модели
best_model_info = max(grid_search_results, key=lambda x: x['best_score'])
best_model_name = best_model_info['model_name']
best_model_params = best_model_info['best_params']
best_model_score = best_model_info['best_score']

print(f"Лучшая модель: {best_model_name}")
print(f"Лучшие параметры: {best_model_params}")
print(f"Лучший ROC-AUC на кросс-валидации: {best_model_score:.4f}\n")

# Создаем pipeline с лучшей моделью
for model in models:
    if model['name'] == best_model_name:
        best_pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('model', model['estimator'].set_params(**{k.split('__')[1]: v for k, v in best_model_params.items()}))
        ])
        break

# Обучаем лучшую модель на всей обучающей выборке
best_pipeline.fit(X_train, y_train)

# 2. Тестирование на тестовой выборке
y_pred_proba = best_pipeline.predict_proba(X_test)[:, 1]

# 3. Нахождение оптимального порога для класса 1
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# Вычисляем F1-score для каждого порога
f1_scores = 2 * (precision * recall) / (precision + recall)
optimal_idx = np.argmax(f1_scores)
optimal_threshold = thresholds[optimal_idx]

print(f"Оптимальный порог для класса 1: {optimal_threshold:.4f}")

# Применяем оптимальный порог
y_pred = (y_pred_proba >= optimal_threshold).astype(int)

# Оцениваем метрики после применения порога
roc_auc = roc_auc_score(y_test, y_pred_proba)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"ROC-AUC на тестовой выборке: {roc_auc:.4f}")
print(f"Accuracy на тестовой выборке: {accuracy:.4f}")
print(f"F1-score на тестовой выборке: {f1:.4f}\n")

# Проверка условия ROC-AUC >= 0.85
if roc_auc < 0.85:
    print("Внимание! Значение ROC-AUC ниже порога 0.85.\n")

# 3. Матрица ошибок
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_pipeline.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Матрица ошибок")
plt.show()

# График точности и полноты
PrecisionRecallDisplay.from_predictions(y_test, y_pred_proba)
plt.title("Точность и полнота")
plt.show()

# 4. Анализ важности признаков
if hasattr(best_pipeline.named_steps['model'], 'feature_importances_'):
    # Извлекаем важность признаков
    feature_importances = best_pipeline.named_steps['model'].feature_importances_
    
    # Получаем имена признаков после преобразования
    feature_names = numeric_features + categorical_features
    
    # Создаем DataFrame для удобства анализа
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': feature_importances
    }).sort_values(by='Importance', ascending=False)
    
    # Визуализация важности признаков
    plt.figure(figsize=(10, 6))
    sns.barplot(data=importance_df.head(10), x='Importance', y='Feature', palette='viridis')
    plt.title("Топ-10 важных признаков")
    plt.xlabel("Важность")
    plt.ylabel("Признак")
    plt.show()
else:
    print("Модель не поддерживает анализ важности признаков.")

# 5. Исследование зависимости одного из важных признаков от целевого
if 'importance_df' in locals():
    most_important_feature = importance_df.iloc[0]['Feature']
    print(f"\nИсследование зависимости признака '{most_important_feature}' от целевого признака:")
    
    # Построение графика зависимости
    plt.figure(figsize=(8, 5))
    sns.boxplot(x='Churn', y=most_important_feature, data=X_test.assign(Churn=y_test))
    plt.title(f"Зависимость '{most_important_feature}' от Churn")
    plt.xlabel("Churn (0 - активные, 1 - ушедшие)")
    plt.ylabel(most_important_feature)
    plt.show()
# Out:
# Лучшая модель: Gradient Boosting
# Лучшие параметры: {'model__class_weight': None, 'model__early_stopping': False, 'model__l2_regularization': 1.0, 'model__learning_rate': 0.2, 'model__max_depth': 3, 'model__max_iter': 500}
# Лучший ROC-AUC на кросс-валидации: 0.8830
#
# Оптимальный порог для класса 1: 0.3341
# ROC-AUC на тестовой выборке: 0.8973
# Accuracy на тестовой выборке: 0.8868
# F1-score на тестовой выборке: 0.6497
# Модель не поддерживает анализ важности признаков.

# %% [markdown]
# ## Выводы

# %% [markdown]
# ### Выводы о моделях
#
# #### Обзор результатов моделей
# В ходе исследования было проведено обучение и оптимизация пяти различных моделей машинного обучения для задачи предсказания оттока клиентов. Каждая модель была настроена с использованием `GridSearchCV` для подбора гиперпараметров, что позволило найти наиболее эффективные параметры для каждой модели.
#
# 1. **Decision Tree**
#    - Лучшие параметры:
#      ```python
#      {'model__class_weight': 'balanced', 'model__max_depth': 5, 'model__min_samples_leaf': 5}
#      ```
#    - Лучший ROC-AUC: 0.7901
#    - Модель Decision Tree показала удовлетворительный результат, но не смогла достичь высоких метрик по сравнению с другими моделями.
#
# 2. **Random Forest**
#    - Лучшие параметры:
#      ```python
#      {'model__class_weight': None, 'model__max_depth': 7, 'model__n_estimators': 200}
#      ```
#    - Лучший ROC-AUC: 0.8199
#    - Random Forest продемонстрировал хорошие результаты, особенно в плане устойчивости к переобучению благодаря ансамблевому подходу.
#
# 3. **Gradient Boosting**
#    - Лучшие параметры:
#      ```python
#      {'model__class_weight': None, 'model__early_stopping': False, 'model__l2_regularization': 1.0, 'model__learning_rate': 0.2, 'model__max_depth': 3, 'model__max_iter': 500}
#      ```
#    - Лучший ROC-AUC: 0.8830
#    - Gradient Boosting показал наилучшие результаты среди всех моделей, достигнув значительного значения ROC-AUC.
#
# 4. **Logistic Regression**
#    - Лучшие параметры:
#      ```python
#      {'model__C': 10, 'model__class_weight': None, 'model__penalty': 'l1', 'model__solver': 'liblinear'}
#      ```
#    - Лучший ROC-AUC: 0.8091
#    - Logistic Regression также показала хорошие результаты, хотя и не так высокие, как у Gradient Boosting.
#
# ---
#
# ### Лучшая модель: Gradient Boosting
#
# #### Результаты лучшей модели
# - **Лучшие параметры**:
#   ```python
#   {'model__class_weight': None, 'model__early_stopping': False, 'model__l2_regularization': 1.0, 'model__learning_rate': 0.2, 'model__max_depth': 3, 'model__max_iter': 500}
#   ```
# - **Метрики на тестовой выборке**:
#   - ROC-AUC: 0.8973
#   - Accuracy: 0.8868
#   - F1-score: 0.6497
#
# #### Анализ результатов
#
# 1. **ROC-AUC = 0.8973**
#    - Высокое значение ROC-AUC указывает на хорошую способность модели различать классы. Это означает, что модель может эффективно ранжировать клиентов по вероятности их оттока.
#
# 2. **Accuracy = 0.8868**
#    - Высокая точность говорит о том, что модель правильно классифицирует большинство клиентов. Однако, стоит помнить, что accuracy может быть не самым информативным показателем для несбалансированных данных.
#
# 3. **F1-score = 0.6497**
#    - F1-score является средним гармоническим между precision и recall. Несмотря на то, что значение не очень высокое, это связано с тем, что модель делает больше ложноположительных предсказаний (FP) для миноритарного класса.
#
# #### Матрица ошибок
#
# - **True Negative (TN)**: 1140 — количество активных клиентов, которые были правильно классифицированы как активные.
# - **False Positive (FP)**: 66 — количество активных клиентов, которые были неправильно классифицированы как ушедшие.
# - **False Negative (FN)**: 99 — количество ушедших клиентов, которые были неправильно классифицированы как активные.
# - **True Positive (TP)**: 153 — количество ушедших клиентов, которые были правильно классифицированы как ушедшие.
#
# #### График точности и полноты
#
# - **Precision**: Показывает долю истинно положительных предсказаний среди всех положительных предсказаний. Значение начинается с 1.0 и снижается по мере увеличения recall.
# - **Recall**: Показывает долю истинно положительных предсказаний среди всех фактически положительных примеров. Значение начинается с 1.0 и снижается по мере уменьшения precision.
# - **AP (Average Precision)**: Средняя точность составляет 0.73, что указывает на достаточно хорошую способность модели находить ушедших клиентов.
#
# ---
#
# ### Заключение
#
# Gradient Boosting оказалась самой эффективной моделью для решения задачи предсказания оттока клиентов. Она продемонстрировала высокие значения метрик, таких как ROC-AUC и Accuracy, что свидетельствует о её способности хорошо различать классы и делать точные предсказания.

# %% [markdown]
# ### Рекомендации для бизнеса на основе анализа оттока клиентов
#
# На основании проведенного анализа данных и построенных моделей, можно выделить несколько ключевых рекомендаций для бизнеса, которые помогут снизить отток клиентов и улучшить их удовлетворенность услугами.
#
# #### 1. **Оптимизация стоимости услуг**
#    - **Высокие платежи** (`LogTotalCharges`, `TotalCharges`) являются одним из наиболее значимых факторов, влияющих на отток клиентов. Клиенты, уплачивающие высокие суммы за услуги, чаще склонны уходить.
#    - **Рекомендация**: Рассмотрите возможность разработки более гибкой системы тарифов, которая бы учитывала потребности различных групп клиентов. Например, предложите специальные пакеты услуг для новых клиентов или лояльных клиентов с длительным контрактом. Также можно ввести скидки для клиентов, оплачивающих услуги авансом на длительный период.
#
# #### 2. **Улучшение поддержки и сервиса**
#    - **Подключение дополнительных услуг** (`NumAdditionalServices`, `HasStreamingServices`, `ProtectionLevel`) также оказывает влияние на отток. Клиенты, не использующие дополнительные услуги, могут чувствовать недостаток в сервисе.
#    - **Рекомендация**: Усиление маркетинговых предложений для продвижения дополнительных услуг, таких как резервное копирование данных (`OnlineBackup`), защита устройств (`DeviceProtection`), техническая поддержка (`TechSupport`). Это поможет повысить уровень удовлетворенности клиентов и снизить вероятность их ухода.
#
# #### 3. **Анализ демографических характеристик**
#    - **Семейное положение** (`Partner`, `Dependents`) также играет роль в оттоке клиентов. Клиенты без партнера (`Partner`) и детей (`Dependents`) чаще уходят.
#    - **Рекомендация**: Разработка специальных предложений для семейных клиентов, например, семейные тарифы, которые будут включать услуги для всех членов семьи. Это может помочь привлечь и удержать клиентов с семьями.
#
# #### 4. **Оптимизация способов оплаты**
#    - **Способ оплаты** (`PaymentTypeNumeric`, `PaymentMethod`) также влияет на отток. Некоторые способы оплаты могут быть связаны с более высоким оттоком.
#    - **Рекомендация**: Предоставьте клиентам больше вариантов для удобной оплаты, включая автоматические списания с банковских карт или счетов. Это поможет сделать процесс оплаты более простым и удобным для клиентов.
#
# #### 5. **Анализ использования интернет-услуг**
#    - **Тип интернет-услуги** (`HasFiberOptic`, `InternetService`) имеет небольшое влияние на отток, но все же стоит обратить внимание на этот аспект.
#    - **Рекомендация**: Проведите анализ качества предоставляемых интернет-услуг, особенно для клиентов, использующих волоконно-оптическую связь (`HasFiberOptic`). Возможно, есть проблемы с качеством связи или скоростью, которые нужно решить.
#
# #### 6. **Индивидуальный подход к клиентам**
#    - **Важность признаков**, таких как `MonthlyCharges`, `MultipleLines`, указывают на то, что клиенты, уплачивающие высокие ежемесячные платежи и имеющие несколько телефонных линий, чаще уходят.
#    - **Рекомендация**: Внедрите систему мониторинга клиентов, которая будет выявлять потенциально уходящих клиентов на основе их поведения и предложить им индивидуальные предложения или консультации для решения их проблем.
#
# #### 7. **Использование моделей машинного обучения**
#    - **Построенные модели** (`Decision Tree`, `Random Forest`, `Gradient Boosting`, `Logistic Regression`) показали хорошие результаты в предсказании оттока клиентов.
#    - **Рекомендация**: Используйте эти модели для регулярного прогнозирования оттока клиентов и принятия оперативных мер по удержанию. Модели могут помочь выявить клиентов, которые находятся в зоне риска, и предложить им специальные предложения или консультации.
#
# #### 8. **Анализ важности признаков**
#    - **Глобальная важность признаков** показала, что некоторые признаки имеют большее влияние на отток, чем другие.
#    - **Рекомендация**: Основываясь на важности признаков, можно фокусироваться на тех аспектах бизнеса, которые имеют наибольшее влияние на отток. Например, если `LogTotalCharges` является наиболее важным признаком, то следует сосредоточиться на оптимизации стоимости услуг.
#
# ### Заключение
# Применение данных рекомендаций позволит компании улучшить качество предоставляемых услуг, снизить отток клиентов и увеличить их удовлетворенность. Важно регулярно проводить анализ данных и адаптировать стратегии удержания клиентов в соответствии с текущими тенденциями и потребностями рынка.
